# %%
import turtle
tl=turtle.Turtle()
tl.speed(7)
a=150
b=100
tl.circle(b)
tl.penup()
tl.right(90)
tl.forward(a*2)
tl.left(90)
tl.pendown()
tl.circle(a)
tl.left(90)
tl.penup()
tl.forward(280)
tl.left(90)
tl.fillcolor('blue')
tl.pencolor('blue')
tl.begin_fill()
tl.pendown()
tl.forward(120)
tl.right(90)
tl.forward(40)
tl.right(90)
tl.forward(240)
tl.right(90)
tl.forward(40)
tl.right(90)
tl.forward(240)
tl.left(90)
tl.forward(50)
tl.left(90)
tl.forward(20)
tl.left(90)
tl.forward(50)
tl.right(180)
tl.forward(70)
tl.left(90)
tl.forward(30)
tl.left(90)
tl.forward(70)
tl.end_fill()
tl.right(90)
tl.forward(55)
tl.right(90)
tl.penup()
tl.fillcolor('red')
tl.pencolor('red')
tl.begin_fill()
tl.forward(63)
tl.pendown()
tl.circle(10)
tl.penup()
tl.forward(63)
tl.pendown()
tl.circle(10)
tl.penup()
tl.forward(63)
tl.pendown()
tl.circle(10)
tl.end_fill()
tl.penup()
tl.right(90)
tl.forward(130)
tl.right(90)
tl.forward(90)
tl.pendown()
tl.left(45)
tl.pensize(5)
tl.pencolor('brown')
tl.forward(90)
tl.right(180)
tl.forward(35)
tl.left(135)
tl.forward(35)
tl.right(180)
tl.forward(35)
tl.right(100)
tl.forward(35)
tl.penup()
tl.right(180)
tl.forward(35)
tl.right(45)
tl.forward(55)
tl.left(55)
tl.forward(300)
tl.pendown()
tl.pensize(5)
tl.pencolor('brown')
tl.left(45)
tl.forward(90)
tl.right(180)
tl.forward(35)
tl.right(135)
tl.forward(35)
tl.right(180)
tl.forward(35)
tl.left(90)
tl.forward(35)
tl.penup()
tl.left(90)
tl.forward(220)
tl.left(90)
tl.forward(170)
tl.pendown()
tl.pencolor('black')
tl.fillcolor('black')
tl.begin_fill()
tl.circle(10)
tl.penup()
tl.forward(100)
tl.pendown()
tl.circle(10)
tl.end_fill()
tl.penup()
tl.left(90)
tl.forward(70)
tl.left(45)
tl.pendown()
tl.circle(75,90)
tl.penup()
tl.left(110)
tl.forward(60)
tl.pendown()
tl.pensize(2)
tl.fillcolor('orange')
tl.pencolor('orange')
tl.begin_fill()
tl.right(20)
tl.forward(25)
tl.right(135)
tl.forward(30)
tl.right(115)
tl.forward(20)
tl.end_fill()
tl.penup()
tl.right(153)
tl.forward(90)
tl.right(90)
tl.pendown()
tl.fillcolor('red')
tl.pencolor('red')
tl.begin_fill()
tl.forward(100)
tl.left(180)
tl.forward(200)
tl.right(120)
tl.forward(200)
tl.right(120)
tl.forward(200)
tl.end_fill()
tl.right(180)
tl.forward(200)
tl.fillcolor('green')
tl.pencolor('green')
tl.begin_fill()
tl.right(100)
tl.circle(10)
tl.end_fill()

turtle.done()
