# %%
import pandas as pd
import numpy as np
print('Khai báo thành công')
# Out:
# Khai báo thành công

# %%
dt=pd.read_csv('FoodPrice_in_Turkey.csv')
dt.head()
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# 5     National Average         52            Rice - Retail     5     KG
# 6     National Average         52            Rice - Retail     5     KG
# 7     National Average         52            Rice - Retail     5     KG
# 8     National Average         52            Rice - Retail     5     KG
# 9     National Average         52            Rice - Retail     5     KG
# 10    National Average         52            Rice - Retail     5     KG
# 11    National Average         52            Rice - Retail     5     KG
# ...

# %%
# Tách file 1 chứa 5000 bản ghi đầu tiên
dt1 = dt.loc[0:4999,:]
dt1
# Out:
#                  Place  ProductId         ProductName  UmId UmName  Month  \
# 0     National Average         52       Rice - Retail     5     KG      5
# 1     National Average         52       Rice - Retail     5     KG      6
# 2     National Average         52       Rice - Retail     5     KG     11
# 3     National Average         52       Rice - Retail     5     KG     12
# 4     National Average         52       Rice - Retail     5     KG      1
# 5     National Average         52       Rice - Retail     5     KG      2
# 6     National Average         52       Rice - Retail     5     KG      3
# 7     National Average         52       Rice - Retail     5     KG      5
# 8     National Average         52       Rice - Retail     5     KG      6
# 9     National Average         52       Rice - Retail     5     KG      7
# 10    National Average         52       Rice - Retail     5     KG      8
# 11    National Average         52       Rice - Retail     5     KG      9
# ...

# %%
# Tách file 2 chứa các bản ghi còn lại
dt2 = dt.loc[5000:7380,:]
dt2
# Out:
#          Place  ProductId              ProductName  UmId UmName  Month  Year  \
# 5000  Istanbul        254         Bananas - Retail     5     KG      2  2017
# 5001  Istanbul        254         Bananas - Retail     5     KG      3  2017
# 5002  Istanbul        254         Bananas - Retail     5     KG      4  2017
# 5003  Istanbul        254         Bananas - Retail     5     KG      5  2017
# 5004  Istanbul        254         Bananas - Retail     5     KG      6  2017
# 5005  Istanbul        254         Bananas - Retail     5     KG      7  2017
# 5006  Istanbul        254         Bananas - Retail     5     KG      8  2017
# 5007  Istanbul        254         Bananas - Retail     5     KG      9  2017
# 5008  Istanbul        254         Bananas - Retail     5     KG     10  2017
# 5009  Istanbul        254         Bananas - Retail     5     KG     11  2017
# 5010  Istanbul        254         Bananas - Retail     5     KG     12  2017
# ...

# %%
# Tách file 3 chứa thông tin giá với số dòng từ bản ghi 1000 đến 2000
dt3 = dt.loc[1000:2000,['ProductId','Place','Month','Year','Price']]
dt3
# Out:
#       ProductId             Place  Month  Year   Price
# 1000        176  National Average      4  2016  4.4000
# 1001        176  National Average      5  2016  4.4600
# 1002        176  National Average      6  2016  4.5400
# 1003        176  National Average      7  2016  4.5700
# 1004        176  National Average      8  2016  4.5900
# 1005        176  National Average      9  2016  4.5900
# 1006        176  National Average     10  2016  4.5200
# 1007        176  National Average     11  2016  4.3100
# 1008        176  National Average     12  2016  4.5500
# 1009        176  National Average      1  2017  4.7200
# 1010        176  National Average      2  2017  4.6100
# 1011        176  National Average      3  2017  4.6500
# 1012        181  National Average     11  2013  1.0915
# 1013        181  National Average     12  2013  1.1181
# 1014        181  National Average      1  2014  1.1632
# 1015        181  National Average      2  2014  1.0786
# ...

# %%
#Ghép 2 dòng từ các file
dt4=pd.concat([dt1,dt2], axis=0)
dt4
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# 5     National Average         52            Rice - Retail     5     KG
# 6     National Average         52            Rice - Retail     5     KG
# 7     National Average         52            Rice - Retail     5     KG
# 8     National Average         52            Rice - Retail     5     KG
# 9     National Average         52            Rice - Retail     5     KG
# 10    National Average         52            Rice - Retail     5     KG
# 11    National Average         52            Rice - Retail     5     KG
# ...

# %%
dt5=pd.concat([dt1,dt2,dt3], axis=0)
dt5
# Out:
# D:\a\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#       Month             Place   Price  ProductId    ProductName  UmId UmName  \
# 0         5  National Average  4.4920         52  Rice - Retail   5.0     KG
# 1         6  National Average  4.5786         52  Rice - Retail   5.0     KG
# 2        11  National Average  4.7865         52  Rice - Retail   5.0     KG
# 3        12  National Average  5.1337         52  Rice - Retail   5.0     KG
# 4         1  National Average  5.5099         52  Rice - Retail   5.0     KG
# 5         2  National Average  5.8146         52  Rice - Retail   5.0     KG
# ...
