# %%
import numpy as np
import pandas as pd
import matplotlib as plt
print ("Khai bao thu vien thanh cong")
# Out:
# Khai bao thu vien thanh cong

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
data=pd.read_csv("/content/gdrive/My Drive/My Drive/codegym/Bai 1/GDPlist.csv",header=0,encoding="ISO-8859-1")
data
# Out:
#           Country      Continent  GDP (millions of US$)
# 0     Afghanistan           Asia                  18181
# 1         Albania         Europe                  12847
# 2         Algeria         Africa                 190709
# 3          Angola         Africa                 100948
# 4       Argentina  South America                 447644
# ..            ...            ...                    ...
# 120    Uzbekistan           Asia                  45353
# 121     Venezuela  South America                 315841
# 122       Vietnam           Asia                 122722
# 123         Yemen         Africa                  33675
# 124        Zambia         Africa                  19206
#
# [125 rows x 3 columns]

# %%
#tim so dong so cot
print("Thong tin ve kich thuoc")
print(data.shape)
print("So dong la: ",data.shape[0], "So cot la: ",data.shape[1])
# Out:
# Thong tin ve kich thuoc
# (125, 3)
# So dong la:  125 So cot la:  3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                125 non-null    object
#  1   Continent              125 non-null    object
#  2   GDP (millions of US$)  125 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.1+ KB

# %%
print("Thuoc tinh cua ",data.columns[0],"la dinh danh nominal")
print("Thuoc tinh cua ",data.columns[1],"la dinh danh nominal")
print("Thuoc tinh cua ",data.columns[2],"la dinh tuong ratio")
# Out:
# Thuoc tinh cua  Country la dinh danh nominal
# Thuoc tinh cua  Continent la dinh danh nominal
# Thuoc tinh cua  GDP (millions of US$) la dinh tuong ratio

# %%
#ve bieu do Histogram the hien GDP
data.hist(column='GDP (millions of US$)',bins=60)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-65700e73cfe5> in <module>()
#       1 #ve bieu do Histogram the hien GDP
#       2 data.hist(column='GDP (millions of US$)',bins=60)
# ----> 3 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
#Cach 2
plt.hist(data['GDP (millions of US$)'],bins=60)
plt.grid(True)
plt.title('GDP (millions os US$)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-b9e39e2e6675> in <module>()
#       1 #Cach 2
# ----> 2 plt.hist(data['GDP (millions of US$)'],bins=60)
#       3 plt.grid(True)
#       4 plt.title('GDP (millions os US$)')
#       5 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'hist'

# %%
#Moi chau luc co bao nhieu quoc gia
print("Trong thong ke co ca chau luc la: ",end=' ')
print(*data['Continent'].unique(),sep=',')
print("So luong chau luc la: ",data['Continent'].unique().size)
# Out:
# Trong thong ke co ca chau luc la:  Asia,Europe,Africa,South America,Oceania,North America
# So luong chau luc la:  6

# %%
#Tong GDP cac Chau luc
gdp=data.groupby('Continent')['GDP (millions of US$)'].sum()
print(gdp)
# Out:
# Continent
# Africa            1820811
# Asia             24425891
# Europe           19139380
# North America    18238447
# Oceania           1662727
# South America     4141217
# Name: GDP (millions of US$), dtype: int64

# %%
print("Tong GDP cua cac Chau luc: ",end=' ')
print(*data['Continent'].unique(),sep=' , ', end='\n')
print("Lan luot la:",end=' ')
print(*gdp,sep=' , ',end='millions of US$.')
# Out:
# Tong GDP cua cac Chau luc:  Asia , Europe , Africa , South America , Oceania , North America
# Lan luot la: 1820811 , 24425891 , 19139380 , 18238447 , 1662727 , 4141217	millions of US$.

# %%
#Top 10 quoc gia co GDP cao nhat
top=data.groupby('Country')['GDP (millions of US$)'].sum().sort_values(ascending=False)
top10=top.head(10)
top10
# Out:
# Country
#  United States     15094025
#  China              7298147
#  Japan              5869471
#  Germany            3577031
#  France             2776324
#  Brazil             2492908
#  United Kingdom     2417570
#  Italy              2198730
#  Russia             1850401
#  Canada             1736869
# Name: GDP (millions of US$), dtype: int64
