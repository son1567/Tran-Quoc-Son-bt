# %%
import pandas as pd
import numpy as np
print("Khai bao thu vien thanh cong")
# Out:
# Khai bao thu vien thanh cong

# %%
dt=pd.read_csv("FoodPrice_in_Turkey.csv",header=0,encoding="ISO-8859-1")
dt
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# 5     National Average         52            Rice - Retail     5     KG
# 6     National Average         52            Rice - Retail     5     KG
# 7     National Average         52            Rice - Retail     5     KG
# 8     National Average         52            Rice - Retail     5     KG
# 9     National Average         52            Rice - Retail     5     KG
# 10    National Average         52            Rice - Retail     5     KG
# 11    National Average         52            Rice - Retail     5     KG
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
# Place          7381 non-null object
# ProductId      7381 non-null int64
# ProductName    7381 non-null object
# UmId           7381 non-null int64
# UmName         7381 non-null object
# Month          7381 non-null int64
# Year           7381 non-null int64
# Price          7381 non-null float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %%
#Đổi tên cột
dt.columns=['Địa điểm','Mã Sp','Tên Sp','Số lượng','Đơn vị','Tháng','Năm','Giá tiền']
dt
# Out:
#               Địa điểm  Mã Sp                   Tên Sp  Số lượng Đơn vị  \
# 0     National Average     52            Rice - Retail         5     KG
# 1     National Average     52            Rice - Retail         5     KG
# 2     National Average     52            Rice - Retail         5     KG
# 3     National Average     52            Rice - Retail         5     KG
# 4     National Average     52            Rice - Retail         5     KG
# 5     National Average     52            Rice - Retail         5     KG
# 6     National Average     52            Rice - Retail         5     KG
# 7     National Average     52            Rice - Retail         5     KG
# 8     National Average     52            Rice - Retail         5     KG
# 9     National Average     52            Rice - Retail         5     KG
# 10    National Average     52            Rice - Retail         5     KG
# 11    National Average     52            Rice - Retail         5     KG
# ...

# %%
dt['new']=np.NaN
dt
# Out:
#               Địa điểm  Mã Sp                   Tên Sp  Số lượng Đơn vị  \
# 0     National Average     52            Rice - Retail         5     KG
# 1     National Average     52            Rice - Retail         5     KG
# 2     National Average     52            Rice - Retail         5     KG
# 3     National Average     52            Rice - Retail         5     KG
# 4     National Average     52            Rice - Retail         5     KG
# 5     National Average     52            Rice - Retail         5     KG
# 6     National Average     52            Rice - Retail         5     KG
# 7     National Average     52            Rice - Retail         5     KG
# 8     National Average     52            Rice - Retail         5     KG
# 9     National Average     52            Rice - Retail         5     KG
# 10    National Average     52            Rice - Retail         5     KG
# 11    National Average     52            Rice - Retail         5     KG
# ...

# %%
#them cot chiet khau
dt.insert(8,'Chiet khau (%)',np.random.randint(0,20,size=(dt.shape[0],1)))
dt
# Out:
#               Địa điểm  Mã Sp                   Tên Sp  Số lượng Đơn vị  \
# 0     National Average     52            Rice - Retail         5     KG
# 1     National Average     52            Rice - Retail         5     KG
# 2     National Average     52            Rice - Retail         5     KG
# 3     National Average     52            Rice - Retail         5     KG
# 4     National Average     52            Rice - Retail         5     KG
# 5     National Average     52            Rice - Retail         5     KG
# 6     National Average     52            Rice - Retail         5     KG
# 7     National Average     52            Rice - Retail         5     KG
# 8     National Average     52            Rice - Retail         5     KG
# 9     National Average     52            Rice - Retail         5     KG
# 10    National Average     52            Rice - Retail         5     KG
# 11    National Average     52            Rice - Retail         5     KG
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 10 columns):
# Địa điểm          7381 non-null object
# Mã Sp             7381 non-null int64
# Tên Sp            7381 non-null object
# Số lượng          7381 non-null int64
# Đơn vị            7381 non-null object
# Tháng             7381 non-null int64
# Năm               7381 non-null int64
# Giá tiền          7381 non-null float64
# Chiet khau (%)    7381 non-null int32
# new               0 non-null float64
# dtypes: float64(2), int32(1), int64(4), object(3)
# memory usage: 547.9+ KB

# %%
#them dong
dt=dt.append({'Địa điểm':'NA','Mã Sp':'503','Ten Sp':'nep','Số lượng':'7','Đơn vị':'KG','Tháng':'9','Năm':'2022','Giá tiền':'50.6545','Chiet khau (%)':'10','new':'NaN'},ignore_index=True)
dt.tail()
# Out:
#      Địa điểm Mã Sp                   Tên Sp Số lượng Đơn vị Tháng   Năm  \
# 7377    Izmir   502  Cocoa (powder) - Retail        5     KG     9  2019
# 7378    Izmir   502  Cocoa (powder) - Retail        5     KG    10  2019
# 7379    Izmir   502  Cocoa (powder) - Retail        5     KG    11  2019
# 7380    Izmir   502  Cocoa (powder) - Retail        5     KG    12  2019
# 7381       NA   503                      NaN        7     KG     9  2022
#
#      Giá tiền Chiet khau (%)  new Ten Sp
# 7377  49.1176              7  NaN    NaN
# 7378  50.8347              5  NaN    NaN
# 7379  51.7985              8  NaN    NaN
# 7380  51.6071             15  NaN    NaN
# 7381  50.6545             10  NaN    nep

# %%
#xoa cot
del dt['new']
dt.head()
# Out:
#            Địa điểm Mã Sp         Tên Sp Số lượng Đơn vị Tháng   Năm Giá tiền  \
# 0  National Average    52  Rice - Retail        5     KG     5  2013    4.492
# 1  National Average    52  Rice - Retail        5     KG     6  2013   4.5786
# 2  National Average    52  Rice - Retail        5     KG    11  2013   4.7865
# 3  National Average    52  Rice - Retail        5     KG    12  2013   5.1337
# 4  National Average    52  Rice - Retail        5     KG     1  2014   5.5099
#
#   Chiet khau (%) Ten Sp
# 0             19    NaN
# 1              9    NaN
# 2              1    NaN
# 3             11    NaN
# 4              8    NaN

# %%
#xoa cot bang pop()
dt.pop('Chiet khau (%)')
dt.head()
# Out:
#            Địa điểm Mã Sp         Tên Sp Số lượng Đơn vị Tháng   Năm Giá tiền  \
# 0  National Average    52  Rice - Retail        5     KG     5  2013    4.492
# 1  National Average    52  Rice - Retail        5     KG     6  2013   4.5786
# 2  National Average    52  Rice - Retail        5     KG    11  2013   4.7865
# 3  National Average    52  Rice - Retail        5     KG    12  2013   5.1337
# 4  National Average    52  Rice - Retail        5     KG     1  2014   5.5099
#
#   Ten Sp
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
#xoa 1 cot bằng drop()
dt.drop('Địa điểm',axis=1,inplace=True)
dt.tail()
# Out:
#      Mã Sp                   Tên Sp Số lượng Đơn vị Tháng   Năm Giá tiền  \
# 7377   502  Cocoa (powder) - Retail        5     KG     9  2019  49.1176
# 7378   502  Cocoa (powder) - Retail        5     KG    10  2019  50.8347
# 7379   502  Cocoa (powder) - Retail        5     KG    11  2019  51.7985
# 7380   502  Cocoa (powder) - Retail        5     KG    12  2019  51.6071
# 7381   503                      NaN        7     KG     9  2022  50.6545
#
#      Ten Sp
# 7377    NaN
# 7378    NaN
# 7379    NaN
# 7380    NaN
# 7381    nep

# %%
dt.drop(['Tháng','Năm'],axis=1,inplace=True)
dt.head()
# Out:
#   Mã Sp         Tên Sp Số lượng Đơn vị Giá tiền Ten Sp
# 0    52  Rice - Retail        5     KG    4.492    NaN
# 1    52  Rice - Retail        5     KG   4.5786    NaN
# 2    52  Rice - Retail        5     KG   4.7865    NaN
# 3    52  Rice - Retail        5     KG   5.1337    NaN
# 4    52  Rice - Retail        5     KG   5.5099    NaN

# %%
#xoa 1 dong bang drop()
dt.drop(7381,axis=0,inplace=True)
dt.tail()
# Out:
#      Mã Sp                   Tên Sp Số lượng Đơn vị Giá tiền Ten Sp
# 7376   502  Cocoa (powder) - Retail        5     KG   47.904    NaN
# 7377   502  Cocoa (powder) - Retail        5     KG  49.1176    NaN
# 7378   502  Cocoa (powder) - Retail        5     KG  50.8347    NaN
# 7379   502  Cocoa (powder) - Retail        5     KG  51.7985    NaN
# 7380   502  Cocoa (powder) - Retail        5     KG  51.6071    NaN

# %%
#xoa nhieu dong (7376,7377)
dt.drop([7376,7377],inplace=True)
dt.tail()
# Out:
#      Mã Sp                   Tên Sp Số lượng Đơn vị Giá tiền Ten Sp
# 7374   502  Cocoa (powder) - Retail        5     KG  46.4609    NaN
# 7375   502  Cocoa (powder) - Retail        5     KG   47.401    NaN
# 7378   502  Cocoa (powder) - Retail        5     KG  50.8347    NaN
# 7379   502  Cocoa (powder) - Retail        5     KG  51.7985    NaN
# 7380   502  Cocoa (powder) - Retail        5     KG  51.6071    NaN
