# %%
import pandas as pd
import numpy as np
print('Khai bao thu vien thanh cong')
# Out:
# Khai bao thu vien thanh cong

# %%
dt=pd.read_csv('FoodPrice_in_Turkey.csv')
dt.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
#Truy cap dong co chi so 3 cua du lieu
dg=dt.iloc[3]
dg
# Out:
# Place          National Average
# ProductId                    52
# ProductName       Rice - Retail
# UmId                          5
# UmName                       KG
# Month                        12
# Year                       2013
# Price                    5.1337
# Name: 3, dtype: object

# %%
#Truy cap dong co chi so tu 4 toi 9
df=dt.iloc[4:9]
df
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 4  National Average         52  Rice - Retail     5     KG      1  2014
# 5  National Average         52  Rice - Retail     5     KG      2  2014
# 6  National Average         52  Rice - Retail     5     KG      3  2014
# 7  National Average         52  Rice - Retail     5     KG      5  2014
# 8  National Average         52  Rice - Retail     5     KG      6  2014
#
#     Price
# 4  5.5099
# 5  5.8146
# 6  6.0014
# 7  6.3202
# 8  6.6019

# %%
#truy cap cac dong roi rac
fg=dt.iloc[[5,16,25]]
fg
# Out:
#                Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 5   National Average         52  Rice - Retail     5     KG      2  2014
# 16  National Average         52  Rice - Retail     5     KG      2  2015
# 25  National Average         52  Rice - Retail     5     KG     11  2015
#
#      Price
# 5   5.8146
# 16  6.4900
# 25  6.2800

# %%
#truy cap cot thu 3
an=dt.iloc[:,3]
an.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# Name: UmId, dtype: int64

# %%
#truy cap tu cot 5 toi cot 11
am=dt.iloc[:,4:7]
am.head()
# Out:
#   UmName  Month  Year
# 0     KG      5  2013
# 1     KG      6  2013
# 2     KG     11  2013
# 3     KG     12  2013
# 4     KG      1  2014

# %%
#truy cap phan tu tai dong 5 cot 7
pl=dt.iloc[5,7]
pl
# Out:
# 5.8146

# %%
#truy cap cac phan tu tu dong 3 toi dong 6 toi cot 3 toi cot 5
pn=dt.iloc[3:7,3:6]
pn
# Out:
#    UmId UmName  Month
# 3     5     KG     12
# 4     5     KG      1
# 5     5     KG      2
# 6     5     KG      3

# %%
#truy cap cot thu 8 bang loc
pv=dt.loc[:,'Year']
pv.head()
# Out:
# 0    2013
# 1    2013
# 2    2013
# 3    2013
# 4    2014
# Name: Year, dtype: int64

# %%
#Truy cap cot thu 7,8 bang loc
lp=dt.loc[:,['Month','Year']]
lp.head()
# Out:
#    Month  Year
# 0      5  2013
# 1      6  2013
# 2     11  2013
# 3     12  2013
# 4      1  2014

# %%
#truy cap phan tu dong 3 cot 7 bang loc
kl=dt.loc[3,'Price']
kl
# Out:
# 5.1337

# %%
#Truy cap toi phan tu Year >= 2015
km=dt.loc[dt.Year>=2017]
km
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 39    National Average         52            Rice - Retail     5     KG
# 40    National Average         52            Rice - Retail     5     KG
# 41    National Average         52            Rice - Retail     5     KG
# 42    National Average         52            Rice - Retail     5     KG
# 43    National Average         52            Rice - Retail     5     KG
# 44    National Average         52            Rice - Retail     5     KG
# 45    National Average         52            Rice - Retail     5     KG
# 46    National Average         52            Rice - Retail     5     KG
# 47    National Average         52            Rice - Retail     5     KG
# 48    National Average         52            Rice - Retail     5     KG
# 49    National Average         52            Rice - Retail     5     KG
# 50    National Average         52            Rice - Retail     5     KG
# ...

# %%
#Thay so 5 bang so 11 trong toan bo du lieu
dt.replace(5,11,inplace=True)
dt.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail    11     KG     11  2013
# 1  National Average         52  Rice - Retail    11     KG      6  2013
# 2  National Average         52  Rice - Retail    11     KG     11  2013
# 3  National Average         52  Rice - Retail    11     KG     12  2013
# 4  National Average         52  Rice - Retail    11     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
#Thay ProductId tu 52 thanh SSD
dt.replace(52,'SSD',inplace=True)
dt.head()
# Out:
#               Place ProductId    ProductName  UmId UmName  Month  Year   Price
# 0  National Average       SSD  Rice - Retail    11     KG     11  2013  4.4920
# 1  National Average       SSD  Rice - Retail    11     KG      6  2013  4.5786
# 2  National Average       SSD  Rice - Retail    11     KG     11  2013  4.7865
# 3  National Average       SSD  Rice - Retail    11     KG     12  2013  5.1337
# 4  National Average       SSD  Rice - Retail    11     KG      1  2014  5.5099

# %%
#thay gia tri 1 trong cot month thanh 7
dt['']
