# %%
import numpy as np
import pandas as pd
print('Khai bao thu vien thanh cong')
# Out:
# Khai bao thu vien thanh cong

# %%
from google.colab import drive
drive.mount('/content/grive')
# Out:
# Mounted at /content/grive

# %%
df=pd.read_csv('/content/grive/My Drive/My Drive/codegym/Bai 1/FoodPrice_in_Turkey.csv',header=0,encoding='ISO-8859-1')
df
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %%
print(df.shape)
print("So dong la: ",df.shape[0],"\n","So cot la: ",df.shape[1])
# Out:
# (7381, 8)
# So dong la:  7381
#  So cot la:  8

# %%
df['cot moi']=np.NaN
df
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price  cot moi
# 0         5  2013   4.4920      NaN
# ...

# %%
df
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price  Chiet khau (%)  cot moi
# ...

# %%
dt=pd.read_excel('/content/grive/My Drive/tài liệu/house_price_dống-da.xlsx')
dt
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                  title  \
# 0    Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# 1    Bán nhà mặt phố Tây Sơn - 6 tầng. Kinh doanh t...
# 2    Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 3    Bán nhà 6 tầng mới kinh doanh mặt ngõ 1194 Đườ...
# 4    Bán nhà mặt phố Thái Hà 70m2, 5 tầng, 4.5m mặt...
# ..                                                 ...
# 995  Bán nhà mặt phố Yên Lãng, Đống Đa, 65m2, 5T, 1...
# 996  Bán nhà 5 tầng đep MP Yên Lãng giá rẻ, DT 60m2...
# 997  MẶT PHỐ XÃ ĐÀN - KINH DOANH ĐỈNH CAO - 6 TẦNG ...
# 998  Bán nhà mặt hồ Văn Chương, Đống Đa 33m2, 6 tần...
# 999  Bán nhà 5 tầng MP Chùa Bộc hạ giá sốc, tử 58,6...
#
#                                                address   area    price  \
# 0    Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...   50.0  14700.0
# ...
